# %% [markdown]
# <a href="https://colab.research.google.com/github/dusarp/dance-bits-experiments/blob/main/similarity_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def cosine_similarity(vec1, vec2):
    # Ensure the vectors are numpy arrays
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)

    # Compute the dot product
    dot_product = np.dot(vec1, vec2)

    # Compute the magnitudes (norms) of the vectors
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)

    # Compute the cosine similarity
    similarity = dot_product / (norm_vec1 * norm_vec2)

    return similarity

# %%
# Example usage:
# Suppose you have two bone vectors
bone_vector1 = [1, 2, 3]
bone_vector2 = [4, 5, 6]

# %%
def visualize_vectors(vec1, vec2):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Create the origin point
    origin = np.array([0, 0, 0])

    # Plot the first vector
    ax.quiver(origin[0], origin[1], origin[2], vec1[0], vec1[1], vec1[2],
              color='r', label='Vector 1', arrow_length_ratio=0.1)

    # Plot the second vector
    ax.quiver(origin[0], origin[1], origin[2], vec2[0], vec2[1], vec2[2],
              color='b', label='Vector 2', arrow_length_ratio=0.1)

    # Set labels for the axes
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')

    # Set limits for the axes (you can adjust these according to your vectors)
    ax.set_xlim([0, max(vec1[0], vec2[0]) + 1])
    ax.set_ylim([0, max(vec1[1], vec2[1]) + 1])
    ax.set_zlim([0, max(vec1[2], vec2[2]) + 1])

    # Add a legend
    ax.legend()
    plt.show()

# %%
visualize_vectors(bone_vector1, bone_vector2)

# %%
cos_sim = cosine_similarity(bone_vector1, bone_vector2)
print("Cosine Similarity:", cos_sim)
# Out:
# Cosine Similarity: 0.9746318461970762

# %%
bone_vector1 = [1, 2, 3]
bone_vector2 = [1, 4, 3]

# %%
visualize_vectors(bone_vector1, bone_vector2)

# %%
cos_sim = cosine_similarity(bone_vector1, bone_vector2)
print("Cosine Similarity:", cos_sim)
# Out:
# Cosine Similarity: 0.9434563530497265
